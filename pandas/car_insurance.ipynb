# %%
import pandas as pd

# %%
csv_file = 'Car_Insurance.csv'
df = pd.read_csv(csv_file)
print(df)
# Out:
#         Id  Age           Job   Marital  Education  Default  Balance  \
# 0        1   32    management    single   tertiary        0     1218
# 1        2   32   blue-collar   married    primary        0     1156
# 2        3   29    management    single   tertiary        0      637
# 3        4   25       student    single    primary        0      373
# 4        5   30    management   married   tertiary        0     2694
# ...    ...  ...           ...       ...        ...      ...      ...
# 3995  3996   28    technician    single   tertiary        0        0
# 3996  3997   49        admin.  divorced  secondary        0      124
# 3997  3998   27        admin.    single  secondary        0     -400
# 3998  3999   36  entrepreneur    single   tertiary        0      658
# 3999  4000   45      services   married    primary        0      137
#
#       HHInsurance  CarLoan Communication  LastContactDay LastContactMonth  \
# ...

# %%
df.head()
# Out:
#    Id  Age          Job  Marital Education  Default  Balance  HHInsurance  \
# 0   1   32   management   single  tertiary        0     1218            1
# 1   2   32  blue-collar  married   primary        0     1156            1
# 2   3   29   management   single  tertiary        0      637            1
# 3   4   25      student   single   primary        0      373            1
# 4   5   30   management  married  tertiary        0     2694            0
#
#    CarLoan Communication  LastContactDay LastContactMonth  NoOfContacts  \
# 0        0     telephone              28              jan             2
# 1        0           NaN              26              may             5
# 2        0      cellular               3              jun             1
# 3        0      cellular              11              may             2
# 4        0      cellular               3              jun             1
#
#    DaysPassed  PrevAttempts  Outcome CallStart   CallEnd  CarInsurance
# ...

# %%
df.value_counts()
# Out:
# Id    Age  Job            Marital  Education  Default  Balance  HHInsurance  CarLoan  Communication  LastContactDay  LastContactMonth  NoOfContacts  DaysPassed  PrevAttempts  Outcome  CallStart  CallEnd   CarInsurance
# 3     29   management     single   tertiary   0         637     1            0        cellular       3               jun               1             119         1             failure  16:30:24   16:36:04  1               1
# 2702  33   self-employed  single   tertiary   0         562     1            1        cellular       6               apr               1             363         1             failure  16:23:53   16:27:09  1               1
# 2564  35   management     married  secondary  0         724     1            0        cellular       14              jul               2             415         1             failure  15:07:33   15:12:20  1               1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                4000 non-null   int64
#  1   Age               4000 non-null   int64
#  2   Job               3981 non-null   object
#  3   Marital           4000 non-null   object
#  4   Education         3831 non-null   object
#  5   Default           4000 non-null   int64
#  6   Balance           4000 non-null   int64
#  7   HHInsurance       4000 non-null   int64
#  8   CarLoan           4000 non-null   int64
#  9   Communication     3098 non-null   object
#  10  LastContactDay    4000 non-null   int64
#  11  LastContactMonth  4000 non-null   object
#  12  NoOfContacts      4000 non-null   int64
#  13  DaysPassed        4000 non-null   int64
#  14  PrevAttempts      4000 non-null   int64
#  15  Outcome           958 non-null    object
# ...

# %%
df.head()
# Out:
#    Id  Age          Job  Marital Education  Default  Balance  HHInsurance  \
# 0   1   32   management   single  tertiary        0     1218            1
# 1   2   32  blue-collar  married   primary        0     1156            1
# 2   3   29   management   single  tertiary        0      637            1
# 3   4   25      student   single   primary        0      373            1
# 4   5   30   management  married  tertiary        0     2694            0
#
#    CarLoan Communication  LastContactDay LastContactMonth  NoOfContacts  \
# 0        0     telephone              28              jan             2
# 1        0           NaN              26              may             5
# 2        0      cellular               3              jun             1
# 3        0      cellular              11              may             2
# 4        0      cellular               3              jun             1
#
#    DaysPassed  PrevAttempts  Outcome CallStart   CallEnd  CarInsurance
# ...

# %%
for col in df.columns:
    col.count_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 for col in df.columns:
# ----> 2     col.count_values()
#
# AttributeError: 'str' object has no attribute 'count_values'

# %%
df.isna().sum()
# Out:
# Id                     0
# Age                    0
# Job                   19
# Marital                0
# Education            169
# Default                0
# Balance                0
# HHInsurance            0
# CarLoan                0
# Communication        902
# LastContactDay         0
# LastContactMonth       0
# NoOfContacts           0
# DaysPassed             0
# PrevAttempts           0
# Outcome             3042
# CallStart              0
# CallEnd                0
# CarInsurance           0
# dtype: int64

# %%
len(df['Communication'])
# Out:
# 4000

# %%
len(df['Outcome'])
# Out:
# 4000

# %%
drop_rows  = df.dropna(axis=0)

# %%
drop_rows.isna()
# Out:
#          Id    Age    Job  Marital  Education  Default  Balance  HHInsurance  \
# 2     False  False  False    False      False    False    False        False
# 5     False  False  False    False      False    False    False        False
# 15    False  False  False    False      False    False    False        False
# 16    False  False  False    False      False    False    False        False
# 17    False  False  False    False      False    False    False        False
# ...     ...    ...    ...      ...        ...      ...      ...          ...
# 3987  False  False  False    False      False    False    False        False
# 3990  False  False  False    False      False    False    False        False
# 3992  False  False  False    False      False    False    False        False
# 3995  False  False  False    False      False    False    False        False
# 3998  False  False  False    False      False    False    False        False
#
# ...

# %%
drop_rows.describe()
# Out:
#                 Id         Age     Default       Balance  HHInsurance  \
# count   907.000000  907.000000  907.000000    907.000000   907.000000
# mean   2004.713341   41.261301    0.004410   1741.250276     0.509372
# std    1121.137774   12.269017    0.066299   3273.816214     0.500188
# min       3.000000   18.000000    0.000000   -982.000000     0.000000
# 25%    1089.000000   33.000000    0.000000    228.000000     0.000000
# 50%    2019.000000   38.000000    0.000000    724.000000     1.000000
# 75%    2938.500000   48.000000    0.000000   1947.000000     1.000000
# max    3999.000000   82.000000    1.000000  52587.000000     1.000000
#
#           CarLoan  LastContactDay  NoOfContacts  DaysPassed  PrevAttempts  \
# count  907.000000      907.000000    907.000000  907.000000    907.000000
# mean     0.098126       14.407938      1.929438  204.815877      2.987872
# std      0.297649        8.263130      1.394361  118.418023      3.375811
# ...

# %%
drop_rows['Age'].mean()
# Out:
# 41.26130099228225

# %%
unique_job = drop_rows['Job'].unique()
# Out:
# array(['management', 'technician', 'admin.', 'blue-collar', 'retired',
#        'entrepreneur', 'student', 'self-employed', 'services',
#        'unemployed', 'housemaid'], dtype=object)

# %%
count_unique_job = drop_rows['Job'].nunique()
print(count_unique_job)
# Out:
# 11

# %%
count_job = drop_rows['Job'].value_counts()
print(count_job)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 count_job = drop_rows['Job'].value_counts()
#       2 print(count_job)
#
# NameError: name 'drop_rows' is not defined

# %%
len(drop_rows['Job'])
# Out:
# 907

# %%
drop_rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 drop_rows
#
# NameError: name 'drop_rows' is not defined

# %%
print(drop_rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(drop_rows)
#
# NameError: name 'drop_rows' is not defined

# %%
drop_rows
# Out:
#         Id  Age           Job  Marital  Education  Default  Balance  \
# 2        3   29    management   single   tertiary        0      637
# 5        6   32    technician   single   tertiary        0     1625
# 15      16   61    management   single   tertiary        0        2
# 16      17   34        admin.   single  secondary        0       69
# 17      18   46    management  married   tertiary        0     7331
# ...    ...  ...           ...      ...        ...      ...      ...
# 3987  3988   27        admin.  married   tertiary        0     2855
# 3990  3991   27    technician   single  secondary        0      126
# 3992  3993   34    technician  married  secondary        0        0
# 3995  3996   28    technician   single   tertiary        0        0
# 3998  3999   36  entrepreneur   single   tertiary        0      658
#
#       HHInsurance  CarLoan Communication  LastContactDay LastContactMonth  \
# 2               1        0      cellular               3              jun
# ...

# %%
drop_rows['Duration'] = drop_rows['CallEnd'] - drop_rows['CallStart']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# ...

# %%
drop_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 2 to 3998
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                907 non-null    int64
#  1   Age               907 non-null    int64
#  2   Job               907 non-null    object
#  3   Marital           907 non-null    object
#  4   Education         907 non-null    object
#  5   Default           907 non-null    int64
#  6   Balance           907 non-null    int64
#  7   HHInsurance       907 non-null    int64
#  8   CarLoan           907 non-null    int64
#  9   Communication     907 non-null    object
#  10  LastContactDay    907 non-null    int64
#  11  LastContactMonth  907 non-null    object
#  12  NoOfContacts      907 non-null    int64
#  13  DaysPassed        907 non-null    int64
#  14  PrevAttempts      907 non-null    int64
#  15  Outcome           907 non-null    object
# ...

# %%
new_df = drop_rows

# %%
new_df['CallEnd'] = pd.to_timedelta(new_df['CallEnd'])
# Out:
# /var/folders/t7/ngplqgr11kl90n5dxvw9shcw0000gn/T/ipykernel_977/2430319555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['CallEnd'] = pd.to_timedelta(new_df['CallEnd'])

# %%
new_df['CallStart'] = pd.to_timedelta(new_df['CallStart'])
# Out:
# /var/folders/t7/ngplqgr11kl90n5dxvw9shcw0000gn/T/ipykernel_977/522704824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['CallStart'] = pd.to_timedelta(new_df['CallStart'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 2 to 3998
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                907 non-null    int64
#  1   Age               907 non-null    int64
#  2   Job               907 non-null    object
#  3   Marital           907 non-null    object
#  4   Education         907 non-null    object
#  5   Default           907 non-null    int64
#  6   Balance           907 non-null    int64
#  7   HHInsurance       907 non-null    int64
#  8   CarLoan           907 non-null    int64
#  9   Communication     907 non-null    object
#  10  LastContactDay    907 non-null    int64
#  11  LastContactMonth  907 non-null    object
#  12  NoOfContacts      907 non-null    int64
#  13  DaysPassed        907 non-null    int64
#  14  PrevAttempts      907 non-null    int64
#  15  Outcome           907 non-null    object
# ...

# %%
new_df['Duration'] = new_df['CallEnd'] - new_df['CallStart']
# Out:
# /var/folders/t7/ngplqgr11kl90n5dxvw9shcw0000gn/T/ipykernel_977/1932665456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Duration'] = new_df['CallEnd'] - new_df['CallStart']

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 2 to 3998
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                907 non-null    int64
#  1   Age               907 non-null    int64
#  2   Job               907 non-null    object
#  3   Marital           907 non-null    object
#  4   Education         907 non-null    object
#  5   Default           907 non-null    int64
#  6   Balance           907 non-null    int64
#  7   HHInsurance       907 non-null    int64
#  8   CarLoan           907 non-null    int64
#  9   Communication     907 non-null    object
#  10  LastContactDay    907 non-null    int64
#  11  LastContactMonth  907 non-null    object
#  12  NoOfContacts      907 non-null    int64
#  13  DaysPassed        907 non-null    int64
#  14  PrevAttempts      907 non-null    int64
#  15  Outcome           907 non-null    object
# ...

# %%
new_df['CallEnd']
# Out:
# 2       16:36:04
# 5       15:11:24
# 15      16:20:59
# 16      11:50:17
# 17      11:34:24
#           ...
# 3987    09:59:44
# 3990    13:33:16
# 3992    10:55:10
# 3995    17:50:57
# 3998    11:29:14
# Name: CallEnd, Length: 907, dtype: object

# %%
new_df['Duration'] = new_df['Duration'].dt.total_seconds()
# Out:
# /var/folders/t7/ngplqgr11kl90n5dxvw9shcw0000gn/T/ipykernel_977/1267383652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Duration'] = new_df['Duration'].dt.total_seconds()

# %%
new_df['Duration'].mean()
# Out:
# 335.74862183020946

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 2 to 3998
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                907 non-null    int64
#  1   Age               907 non-null    int64
#  2   Job               907 non-null    object
#  3   Marital           907 non-null    object
#  4   Education         907 non-null    object
#  5   Default           907 non-null    int64
#  6   Balance           907 non-null    int64
#  7   HHInsurance       907 non-null    int64
#  8   CarLoan           907 non-null    int64
#  9   Communication     907 non-null    object
#  10  LastContactDay    907 non-null    int64
#  11  LastContactMonth  907 non-null    object
#  12  NoOfContacts      907 non-null    int64
#  13  DaysPassed        907 non-null    int64
#  14  PrevAttempts      907 non-null    int64
#  15  Outcome           907 non-null    object
# ...

# %%
new_df['LastContactMonth']
# Out:
# 2       jun
# 5       may
# 15      aug
# 16      may
# 17      sep
#        ...
# 3987    jan
# 3990    feb
# 3992    aug
# 3995    may
# 3998    jan
# Name: LastContactMonth, Length: 907, dtype: object

# %%
new_df['Communication']
# Out:
# 2        cellular
# 5        cellular
# 15       cellular
# 16      telephone
# 17       cellular
#           ...
# 3987     cellular
# 3990     cellular
# 3992     cellular
# 3995     cellular
# 3998     cellular
# Name: Communication, Length: 907, dtype: object

# %%
grouped_month = new_df.groupby('LastContactMonth')

# %%
new_df['LastContactMonth'].nunique()
# Out:
# 12

# %%
month_list = ['jan','feb','mar','apr','may','jun']
if new_df['LastContactMonth'] in month_list:
    new_df['Communication']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t7/ngplqgr11kl90n5dxvw9shcw0000gn/T/ipykernel_977/1518424055.py in ?()
#       1 month_list = ['jan','feb','mar','apr','may','jun']
# ----> 2 if new_df['LastContactMonth'] in month_list:
#       3     new_df['Communication']
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
month_list = ['jan','feb','mar','apr','may','jun']
cell = 0

x = (new_df['LastContactMonth']=='jan').sum()
c = (new_df['LastContactMonth']=='feb').sum()     
v = (new_df['LastContactMonth']=='mar').sum()
b = (new_df['LastContactMonth']=='apr').sum()
n = (new_df['LastContactMonth']=='may').sum()
m = (new_df['LastContactMonth']=='jun').sum()
first_half_year = x+c+v+b+n+m
# Out:
# 526

# %%
pd.to_timedelta(new_df['LastContactMonth'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File timedeltas.pyx:444, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File timedeltas.pyx:476, in pandas._libs.tslibs.timedeltas._item_to_timedelta64_fastpath()
#
# File timedeltas.pyx:653, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: unit abbreviation w/o a number
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File timedeltas.pyx:488, in pandas._libs.tslibs.timedeltas._item_to_timedelta64()
#
# File timedeltas.pyx:367, in pandas._libs.tslibs.timedeltas.convert_to_timedelta64()
#
# File timedeltas.pyx:653, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: unit abbreviation w/o a number
#
# ...

# %%
month_mapping = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 
                 'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

new_df['LastContactMonth'].str.capitalize()
# Out:
# 2       Jun
# 5       May
# 15      Aug
# 16      May
# 17      Sep
#        ...
# 3987    Jan
# 3990    Feb
# 3992    Aug
# 3995    May
# 3998    Jan
# Name: LastContactMonth, Length: 907, dtype: object

# %%
new_df['LastContactMonth'] = new_df['LastContactMonth'].map(month_mapping).apply(lambda x: pd.Timestamp(f'2023-{x:02d}-01'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 new_df['LastContactMonth'] = new_df['LastContactMonth'].map(month_mapping).apply(lambda x: pd.Timestamp(f'2023-{x:02d}-01'))
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# ...

# %%
new_df.groupby(['Communication', 'LastContactMonth'])
# Out:
#                                     Id   Age  \
# Communication LastContactMonth
# cellular      apr               188685  3482
#               aug               176385  3408
#               dec                40682   740
#               feb               170391  3800
#               jan                97167  1879
#               jul                68286  1505
#               jun                94790  1803
#               mar                33686   917
#               may               403982  7594
#               nov               213034  4437
#               oct                93479  2029
#               sep               116871  2345
# telephone     apr                 7785   200
#               aug                 7875   283
#               dec                 4988   152
#               feb                 7701   220
#               jan                 3138   147
#               jul                10024   284
#               jun                 9642   176
# ...

# %%
month_list = ['jan','feb','mar','apr','may','jun']

x = (new_df['LastContactMonth']=='jan').sum()
c = (new_df['LastContactMonth']=='feb').sum()     
v = (new_df['LastContactMonth']=='mar').sum()
b = (new_df['LastContactMonth']=='apr').sum()
n = (new_df['LastContactMonth']=='may').sum()
m = (new_df['LastContactMonth']=='jun').sum()
first_half_year = x+c+v+b+n+m
